# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>

# %% [markdown]
# # Image Classification Competition Model Submission Guide
#
# ---
#
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data / Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting aimodelshare
#   Downloading aimodelshare-0.0.159-py3-none-any.whl (952 kB)
#      |████████████████████████████████| 952 kB 4.3 MB/s
# Collecting PyJWT>=2.4.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting keras2onnx>=1.7.0
#   Downloading keras2onnx-1.7.0-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 5.2 MB/s
# Collecting wget==3.2
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: seaborn>=0.11.2 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (0.11.2)
# Collecting onnxmltools>=1.6.1
#   Downloading onnxmltools-1.11.1-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 55.0 MB/s
# Requirement already satisfied: tensorflow==2.9.2 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (2.9.2)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.13.0+cu116)
# Collecting shortuuid>=1.0.8
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting boto3==1.21.20
#   Downloading boto3-1.21.20-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 61.7 MB/s
# Requirement already satisfied: pydot==1.3.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.3.0)
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      |████████████████████████████████| 24.9 MB 90.3 MB/s
# Collecting tf2onnx
#   Downloading tf2onnx-1.13.0-py3-none-any.whl (442 kB)
#      |████████████████████████████████| 442 kB 55.1 MB/s
# Collecting psutil>=5.9.1
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      |████████████████████████████████| 280 kB 62.9 MB/s
# Collecting Pympler==0.9
#   Downloading Pympler-0.9.tar.gz (178 kB)
#      |████████████████████████████████| 178 kB 65.0 MB/s
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.6.3)
# Requirement already satisfied: importlib-resources==5.10.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (5.10.0)
# Collecting onnx==1.12.0
#   Downloading onnx-1.12.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      |████████████████████████████████| 13.1 MB 67.9 MB/s
# Collecting botocore==1.24.20
#   Downloading botocore-1.24.20-py3-none-any.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 59.9 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (2022.6.2)
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.0.1)
# Collecting onnxruntime>=1.7.0
#   Downloading onnxruntime-1.13.1-cp38-cp38-manylinux_2_27_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 51.4 MB/s
# Collecting docker==5.0.0
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 63.6 MB/s
# Collecting onnxconverter-common>=1.7.0
#   Downloading onnxconverter_common-1.13.0-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 2.7 MB/s
# Collecting skl2onnx>=1.8.0
#   Downloading skl2onnx-1.13-py2.py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 64.5 MB/s
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse==1.6.3->aimodelshare) (0.38.4)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.8/dist-packages (from astunparse==1.6.3->aimodelshare) (1.15.0)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 9.1 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore==1.24.20->aimodelshare) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 61.7 MB/s
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /usr/local/lib/python3.8/dist-packages (from docker==5.0.0->aimodelshare) (2.23.0)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.4.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.5 MB/s
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources==5.10.0->aimodelshare) (3.11.0)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (3.19.6)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (4.4.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.8/dist-packages (from pydot==1.3.0->aimodelshare) (3.0.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (3.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (1.2.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.28.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.2.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.12)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.51.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.1.2)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.1.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (14.0.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (21.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (57.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (3.1.0)
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 6.5 MB/s
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.9 MB/s
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from onnxruntime>=1.7.0->aimodelshare) (1.7.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2022.9.24)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 58.0 MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2.10)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.8/dist-packages (from seaborn>=0.11.2->aimodelshare) (3.2.2)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.8/dist-packages (from seaborn>=0.11.2->aimodelshare) (1.3.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.23->seaborn>=0.11.2->aimodelshare) (2022.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.15.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.13.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.2.2)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.2 MB/s
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy->onnxruntime>=1.7.0->aimodelshare) (1.2.1)
# Building wheels for collected packages: Pympler, wget, fire
#   Building wheel for Pympler (setup.py) ... done
#   Created wheel for Pympler: filename=Pympler-0.9-py3-none-any.whl size=164822 sha256=8e13443c3731a2d7ee724219c53db0c4beea0f3f1f283980bac2f7c9f03f4c91
#   Stored in directory: /root/.cache/pip/wheels/24/6f/0b/da9f81234859a8741aaea3afcc6ae2daf0efb67e7ff2d3686c
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=431f3857965b7beab6d21444ea460eee0c6cd9c4d9cce7d558702cb0c5d445d0
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116949 sha256=7646113e513750f414f718d98bec132ec7fb801c828b1ec9c81ec6cb498df4b0
#   Stored in directory: /root/.cache/pip/wheels/5b/eb/43/7295e71293b218ddfd627f935229bf54af9018add7fbb5aac6
# Successfully built Pympler wget fire
# Installing collected packages: urllib3, onnx, jmespath, scikit-learn, onnxconverter-common, humanfriendly, botocore, websocket-client, skl2onnx, s3transfer, fire, coloredlogs, wget, tf2onnx, shortuuid, Pympler, PyJWT, psutil, onnxruntime, onnxmltools, keras2onnx, docker, boto3, aimodelshare
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed PyJWT-2.6.0 Pympler-0.9 aimodelshare-0.0.159 boto3-1.21.20 botocore-1.24.20 coloredlogs-15.0.1 docker-5.0.0 fire-0.5.0 humanfriendly-10.0 jmespath-0.10.0 keras2onnx-1.7.0 onnx-1.12.0 onnxconverter-common-1.13.0 onnxmltools-1.11.1 onnxruntime-1.13.1 psutil-5.9.4 s3transfer-0.5.2 scikit-learn-0.24.2 shortuuid-1.0.11 skl2onnx-1.13 tf2onnx-1.13.0 urllib3-1.25.11 websocket-client-1.4.2 wget-3.2

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/neuralnet_competition_data-repository:latest')
# Out:
# Downloading [================================================>]
#
# Data downloaded successfully.

# %%
# Create training data objects 

# Extract images
# !unzip "neuralnet_competition_data/X_train.zip"
# !unzip "neuralnet_competition_data/X_test.zip" 

# Create ordered list of filepaths 
train_filepaths = [('/content/train_shuffle/' + str(i) + '.jpg') for i in range(0, 6472)]
test_filepaths = [('/content/test_shuffle/' + str(i) + '.jpg') for i in range(0, 9127)]

# Read in y_train data 
import pandas as pd 
y_train = pd.read_csv("neuralnet_competition_data/y_train.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test_shuffle/8701.jpg
#   inflating: test_shuffle/1057.jpg
#   inflating: test_shuffle/6738.jpg
#   inflating: test_shuffle/7426.jpg
#   inflating: test_shuffle/8715.jpg
#   inflating: test_shuffle/3640.jpg
#   inflating: test_shuffle/3898.jpg
#   inflating: test_shuffle/5231.jpg
#   inflating: test_shuffle/2238.jpg
#   inflating: test_shuffle/4891.jpg
#   inflating: test_shuffle/5557.jpg
#   inflating: test_shuffle/4649.jpg
#   inflating: test_shuffle/3126.jpg
#   inflating: test_shuffle/7340.jpg
#   inflating: test_shuffle/8073.jpg
#   inflating: test_shuffle/1731.jpg
#   inflating: test_shuffle/2210.jpg
#   inflating: test_shuffle/4661.jpg
#   inflating: test_shuffle/7368.jpg
#   inflating: test_shuffle/6076.jpg
#   inflating: test_shuffle/5892.jpg
#   inflating: test_shuffle/4554.jpg
#   inflating: test_shuffle/2125.jpg
#   inflating: test_shuffle/6343.jpg
#   inflating: test_shuffle/9070.jpg
#   inflating: test_shuffle/806.jpg
#   inflating: test_shuffle/8408.jpg
#   inflating: test_shuffle/46.jpg
#   inflating: test_shuffle/6425.jpg
#   inflating: test_shuffle/2643.jpg
#   inflating: test_shuffle/4232.jpg
#   inflating: test_shuffle/8420.jpg
#   inflating: test_shuffle/7713.jpg
#   inflating: test_shuffle/1362.jpg
#   inflating: test_shuffle/5104.jpg
#   inflating: test_shuffle/3575.jpg
#   inflating: test_shuffle/3213.jpg
#   inflating: test_shuffle/5662.jpg
#   inflating: test_shuffle/190.jpg
#   inflating: test_shuffle/1404.jpg
#   inflating: test_shuffle/9058.jpg
#   inflating: test_shuffle/8346.jpg
#   inflating: test_shuffle/7075.jpg
#   inflating: test_shuffle/1410.jpg
#   inflating: test_shuffle/184.jpg
#   inflating: test_shuffle/8352.jpg
#   inflating: test_shuffle/7061.jpg
#   inflating: test_shuffle/3207.jpg
#   inflating: test_shuffle/4568.jpg
#   inflating: test_shuffle/5676.jpg
#   inflating: test_shuffle/2119.jpg
#   inflating: test_shuffle/5110.jpg
#   inflating: test_shuffle/3561.jpg
#   inflating: test_shuffle/8434.jpg
#   inflating: test_shuffle/7707.jpg
#   inflating: test_shuffle/6419.jpg
#   inflating: test_shuffle/1376.jpg

# %% [markdown]
# ##2.   Preprocess data / Write and Save Preprocessor function

# %%
# Here is a pre-designed preprocessor, but you could also build your own to prepare the data differently
import albumentations as A
def preprocessor(image_filepath, shape=(10, 10)):
        """
        This function preprocesses reads in images, resizes them to a fixed shape and
        min/max transforms them before converting feature values to float32 numeric values
        required by onnx files.
        
        params:
            image_filepath
                full filepath of a particular image
                      
        returns:
            X
                numpy array of preprocessed image data
                  
        """
           
        import cv2
        import numpy as np

        "Resize a color image and min/max transform the image"
        img = cv2.imread(image_filepath) # Read in image from filepath.
        img = cv2.resize(img, (64, 64), interpolation = cv2.INTER_CUBIC)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # cv2 reads in images in order of blue green and red, we reverse the order for ML.
        #img = cv2.resize(img, shape) # Change height and width of image.
        
        transform_data = A.Compose([A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, p=1)])
        img = transform_data(image = img)['image']  #custom transform
        #img = img / 255.0 # Min-max transform.


        # Resize all the images...
        X = np.array(img)
        X = np.expand_dims(X, axis=0) # Expand dims to add "1" to object shape [1, h, w, channels].
        X = np.array(X, dtype=np.float32) # Final shape for onnx runtime.

        # transpose image to pytorch format
        X = np.transpose(X, (0, 3, 1, 2))

        return X

# %%
# Use preprocessor to create X_train object 

# Import image, load to array of shape height, width, channels, then min/max transform...
# Read in all images from filenames...
import numpy as np 
import os 

preprocessed_image_data = [preprocessor(x) for x in train_filepaths]

# Object needs to be an array rather than a list for Keras. (vstack converts above list to array object.)
X_train = np.vstack(preprocessed_image_data)
# Assigning to X_train to highlight that this represents feature input data for our model.

# %%
# Preprocess X_test image data to generate predictions from models 
import numpy as np

preprocessed_image_data = [preprocessor(x) for x in test_filepaths]

#Create single X_test array from preprocessed images
X_test = np.vstack(preprocessed_image_data)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
#Let us build a baseline pytorch model and load the trained weights
import torch
import torch.nn as nn
import torchvision
from torchsummary import summary

# Load the EfficientNetB3 model trained on ImageNet
backbone_model = torchvision.models.efficientnet_b3(weights='IMAGENET1K_V1')
backbone_model.classifier = nn.Identity()

# input = torch.rand((1, 3, 64, 64))
# output = backbone_model(input)
# print(output.shape)

class BaselineModel(nn.Module):
    def __init__(self, backbone) -> None:
        super().__init__()
        self.backbone = backbone
        # 3 super classes and 89 + 1 (novel) sub classes
        self.superclass = nn.Linear(in_features = 1536, out_features = 3)
        #self.subclass = nn.Linear(in_features = 1536, out_features = 90)
    
    def forward(self, x):
        out = self.backbone(x)
        super_class_out = self.superclass(out)
        #sub_class_out = self.subclass(out)
        return super_class_out

# Create the baseline EfficientNetB6 model
baseline_model = BaselineModel(backbone_model)

# input = torch.rand((1, 3, 64, 64))
# output = backbone_model(input)
# print(output.shape)
# print(baseline_model)

baseline_model.load_state_dict(torch.load('./Bestmodel_SuperClass.pth', map_location=torch.device('cpu'))['model_state_dict'], strict = True)
# Out:
# <All keys matched successfully>

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save pytorch model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx
example_input = torch.randn(1, 3, 64, 64, requires_grad=True)

onnx_model = model_to_onnx(baseline_model, framework='pytorch',
                           model_input=example_input,
                          transfer_learning=True,
                          deep_learning=True)

with open("baseline_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

# Note -- This is the unique rest api that powers this specific image classification Model Plaground
# ... Update the apiurl if submitting to a new competition

apiurl="https://8vhobca1n7.execute-api.us-east-1.amazonaws.com/prod/m"
set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition

mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted y values (Model 1)
#Note: Keras predict returns the predicted column index location for classification models
# prediction_column_index=cnn1.predict(X_test).argmax(axis=1)
import torch
import numpy as np

X_test_tensor = torch.from_numpy(X_test)
#print(X_test_tensor.shape)

prediction_column_index = np.zeros((X_test_tensor.shape[0]))

for idx in range(0, len(X_test_tensor), 64):
    last_idx = min(idx + 64, len(X_test_tensor))
    if idx % (1280) == 0:
        print(idx)
    
    with torch.no_grad():
        prediction_column_index[idx:last_idx] = (torch.argmax(baseline_model(X_test_tensor[idx:last_idx]), dim = 1)).detach().cpu().numpy()

prediction_column_index = prediction_column_index.astype(np.int32)


# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# print(len(prediction_labels))
# print(prediction_labels[:10])
# Out:
# 0
# 1280
# 2560
# 3840
# 5120
# 6400
# 7680
# 8960

# %%
# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "baseline_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional): None
# Provide any useful notes about your model (optional): None
#
# Your model has been submitted as model version 99
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2651

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_e6495_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 73.8%, transparent 73.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_e6495_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 73.4%, transparent 73.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_e6495_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 72.9%, transparent 72.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_e6495_row0_col3, #T_e6495_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 75.6%, transparent 75.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_e6495_row0_col4, #T_e6495_row0_col5, #T_e6495_row0_col6, #T_e6495_row0_col7, #T_e6495_row0_col8, #T_e6495_row0_col9, #T_e6495_row0_col10, #T_e6495_row0_col11, #T_e6495_row0_col12, #T_e6495_row0_col13, #T_e6495_row0_col14, #T_e6495_row0_col15, #T_e6495_row0_col16, #T_e6495_row0_col17, #T_e6495_row0_col18, #T_e6495_row0_col19, #T_e6495_row0_col20, #T_e6495_row0_col21, #T_e6495_row0_col22, #T_e6495_row0_col23, #T_e6495_row0_col24, #T_e6495_row0_col25, #T_e6495_row0_col26, #T_e6495_row1_col4, #T_e6495_row1_col5, #T_e6495_row1_col6, #T_e6495_row1_col7, #T_e6495_row1_col8, #T_e6495_row1_col9, #T_e6495_row1_col10, #T_e6495_row1_col11, #T_e6495_row1_col12, #T_e6495_row1_col13, #T_e6495_row1_col14, #T_e6495_row1_col15, #T_e6495_row1_col16, #T_e6495_row1_col17, #T_e6495_row1_col18, #T_e6495_row1_col19, #T_e6495_row1_col20, #T_e6495_row1_col21, #T_e6495_row1_col22, #T_e6495_row1_col23, #T_e6495_row1_col24, #T_e6495_row1_col25, #T_e6495_row1_col26, #T_e6495_row2_col4, #T_e6495_row2_col5, #T_e6495_row2_col6, #T_e6495_row2_col7, #T_e6495_row2_col8, #T_e6495_row2_col9, #T_e6495_row2_col10, #T_e6495_row2_col11, #T_e6495_row2_col12, #T_e6495_row2_col13, #T_e6495_row2_col14, #T_e6495_row2_col15, #T_e6495_row2_col16, #T_e6495_row2_col17, #T_e6495_row2_col18, #T_e6495_row2_col19, #T_e6495_row2_col20, #T_e6495_row2_col21, #T_e6495_row2_col22, #T_e6495_row2_col23, #T_e6495_row2_col24, #T_e6495_row2_col25, #T_e6495_row2_col26, #T_e6495_row3_col4, #T_e6495_row3_col5, #T_e6495_row3_col6, #T_e6495_row3_col7, #T_e6495_row3_col8, #T_e6495_row3_col9, #T_e6495_row3_col10, #T_e6495_row3_col11, #T_e6495_row3_col12, #T_e6495_row3_col13, #T_e6495_row3_col14, #T_e6495_row3_col15, #T_e6495_row3_col16, #T_e6495_row3_col17, #T_e6495_row3_col18, #T_e6495_row3_col19, #T_e6495_row3_col20, #T_e6495_row3_col21, #T_e6495_row3_col22, #T_e6495_row3_col23, #T_e6495_row3_col24, #T_e6495_row3_col25, #T_e6495_row3_col26, #T_e6495_row4_col4, #T_e6495_row4_col5, #T_e6495_row4_col6, #T_e6495_row4_col7, #T_e6495_row4_col8, #T_e6495_row4_col9, #T_e6495_row4_col10, #T_e6495_row4_col11, #T_e6495_row4_col12, #T_e6495_row4_col13, #T_e6495_row4_col14, #T_e6495_row4_col15, #T_e6495_row4_col16, #T_e6495_row4_col17, #T_e6495_row4_col18, #T_e6495_row4_col19, #T_e6495_row4_col20, #T_e6495_row4_col21, #T_e6495_row4_col22, #T_e6495_row4_col23, #T_e6495_row4_col24, #T_e6495_row4_col25, #T_e6495_row4_col26, #T_e6495_row5_col4, #T_e6495_row5_col5, #T_e6495_row5_col6, #T_e6495_row5_col7, #T_e6495_row5_col8, #T_e6495_row5_col9, #T_e6495_row5_col10, #T_e6495_row5_col11, #T_e6495_row5_col12, #T_e6495_row5_col13, #T_e6495_row5_col14, #T_e6495_row5_col15, #T_e6495_row5_col16, #T_e6495_row5_col17, #T_e6495_row5_col18, #T_e6495_row5_col19, #T_e6495_row5_col20, #T_e6495_row5_col21, #T_e6495_row5_col22, #T_e6495_row5_col23, #T_e6495_row5_col24, #T_e6495_row5_col25, #T_e6495_row5_col26, #T_e6495_row6_col4, #T_e6495_row6_col5, #T_e6495_row6_col6, #T_e6495_row6_col7, #T_e6495_row6_col8, #T_e6495_row6_col9, #T_e6495_row6_col10, #T_e6495_row6_col11, #T_e6495_row6_col12, #T_e6495_row6_col13, #T_e6495_row6_col14, #T_e6495_row6_col15, #T_e6495_row6_col16, #T_e6495_row6_col17, #T_e6495_row6_col18, #T_e6495_row6_col19, #T_e6495_row6_col20, #T_e6495_row6_col21, #T_e6495_row6_col22, #T_e6495_row6_col23, #T_e6495_row6_col24, #T_e6495_row6_col25, #T_e6495_row6_col26, #T_e6495_row7_col4, #T_e6495_row7_col5, #T_e6495_row7_col6, #T_e6495_row7_col7, #T_e6495_row7_col8, #T_e6495_row7_col9, #T_e6495_row7_col10, #T_e6495_row7_col11, #T_e6495_row7_col12, #T_e6495_row7_col13, #T_e6495_row7_col14, #T_e6495_row7_col15, #T_e6495_row7_col16, #T_e6495_row7_col17, #T_e6495_row7_col18, #T_e6495_row7_col19, #T_e6495_row7_col20, #T_e6495_row7_col21, #T_e6495_row7_col22, #T_e6495_row7_col23, #T_e6495_row7_col24, #T_e6495_row7_col25, #T_e6495_row7_col26, #T_e6495_row8_col4, #T_e6495_row8_col5, #T_e6495_row8_col6, #T_e6495_row8_col7, #T_e6495_row8_col8, #T_e6495_row8_col9, #T_e6495_row8_col10, #T_e6495_row8_col11, #T_e6495_row8_col12, # ...

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).

with tf.device('/device:GPU:0'): # "/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.
      cnn2 = Sequential()
      cnn2.add(Dense(64,  input_shape=(10, 10, 3), activation='relu'))
      cnn2.add(Dense(64, activation='relu'))
      cnn2.add(Dense(64, activation='relu'))
      cnn2.add(Flatten())
      cnn2.add(Dense(3, activation='softmax')) 
                                                  
      # Compile model
      cnn2.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

      # Fitting the NN to the Training set
      cnn2.fit(X_train, y_train, 
                    epochs = 1, verbose=1, validation_split=.2)
# Out:
# 162/162 [==============================] - 3s 16ms/step - loss: 0.9773 - accuracy: 0.5237 - val_loss: 0.8513 - val_accuracy: 0.6340

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(cnn2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_column_index=cnn2.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 286/286 [==============================] - 2s 5ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 2
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2651

# %%
# Compare two or more models
data=mycompetition.compare_models([1,2], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_70df8_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_70df8_row0_col0, #T_70df8_row1_col0, #T_70df8_row3_col0, #T_70df8_row4_col0 {
#   background: #fdcdac;
#   color: black;
#   color: black;
# }
# #T_70df8_row0_col1, #T_70df8_row0_col2, #T_70df8_row0_col4, #T_70df8_row0_col5, #T_70df8_row1_col1, #T_70df8_row1_col2, #T_70df8_row1_col4, #T_70df8_row1_col5, #T_70df8_row2_col1, #T_70df8_row2_col2, #T_70df8_row2_col4, #T_70df8_row2_col5, #T_70df8_row3_col1, #T_70df8_row3_col2, #T_70df8_row3_col4, #T_70df8_row3_col5, #T_70df8_row4_col1, #T_70df8_row4_col2, #T_70df8_row4_col4, #T_70df8_row4_col5, #T_70df8_row5_col1, #T_70df8_row5_col2, #T_70df8_row5_col3, #T_70df8_row5_col4, #T_70df8_row5_col5, #T_70df8_row6_col1, #T_70df8_row6_col2, #T_70df8_row6_col3, #T_70df8_row6_col4, #T_70df8_row6_col5, #T_70df8_row7_col1, #T_70df8_row7_col2, #T_70df8_row7_col3, #T_70df8_row7_col4, #T_70df8_row7_col5, #T_70df8_row8_col1, #T_70df8_row8_col2, #T_70df8_row8_col3, #T_70df8_row8_col4, #T_70df8_row8_col5, #T_70df8_row9_col1, #T_70df8_row9_col2, #T_70df8_row9_col3, #T_70df8_row9_col4, #T_70df8_row9_col5, #T_70df8_row10_col1, #T_70df8_row10_col2, #T_70df8_row10_col3, #T_70df8_row10_col4, #T_70df8_row10_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_70df8_row0_col3, #T_70df8_row1_col3, #T_70df8_row2_col3, #T_70df8_row4_col3, #T_70df8_row8_col0, #T_70df8_row10_col0 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_70df8_row2_col0, #T_70df8_row5_col0 {
#   background: #e6f5c9;
#   color: black;
#   color: black;
# }
# #T_70df8_row3_col3, #T_70df8_row7_col0 {
#   background: nan;
#   color: black;
#   color: black;
# }
# #T_70df8_row6_col0, #T_70df8_row9_col0 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_70df8_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_1_Layer</th>
#       <th class="col_heading level0 col1" >Model_1_Shape</th>
#       <th class="col_heading level0 col2" >Model_1_Params</th>
#       <th class="col_heading level0 col3" >Model_2_Layer</th>
#       <th class="col_heading level0 col4" >Model_2_Shape</th>
#       <th class="col_heading level0 col5" >Model_2_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70df8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70df8_row0_col0" class="data row0 col0" >Conv2D</td>
#       <td id="T_70df8_row0_col1" class="data row0 col1" >[None, 10, 10, 16]</td>
#       <td id="T_70df8_row0_col2" class="data row0 col2" >448</td>
#       <td id="T_70df8_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_70df8_row0_col4" class="data row0 col4" >[None, 10, 10, 64]</td>
#       <td id="T_70df8_row0_col5" class="data row0 col5" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_70df8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_70df8_row1_col0" class="data row1 col0" >Conv2D</td>
#       <td id="T_70df8_row1_col1" class="data row1 col1" >[None, 10, 10, 16]</td>
#       <td id="T_70df8_row1_col2" class="data row1 col2" >2320</td>
#       <td id="T_70df8_row1_col3" class="data row1 col3" >Dense</td>
#       <td id="T_70df8_row1_col4" class="data row1 col4" >[None, 10, 10, 64]</td>
#       <td id="T_70df8_row1_col5" class="data row1 col5" >4160.000000</td>
#     </tr>
#     <tr>
#       <th id="T_70df8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_70df8_row2_col0" class="data row2 col0" >MaxPooling2D</td>
#       <td id="T_70df8_row2_col1" class="data row2 col1" >[None, 5, 5, 16]</td>
#       <td id="T_70df8_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_70df8_row2_col3" class="data row2 col3" >Dense</td>
#       <td id="T_70df8_row2_col4" class="data row2 col4" >[None, 10, 10, 64]</td>
#       <td id="T_70df8_row2_col5" class="data row2 col5" >4160.000000</td>
#     </tr>
#     <tr>
#       <th id="T_70df8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_70df8_row3_col0" class="data row3 col0" >Conv2D</td>
#       <td id="T_70df8_row3_col1" class="data row3 col1" >[None, 5, 5, 16]</td>
#       <td id="T_70df8_row3_col2" class="data row3 col2" >2320</td>
#       <td id="T_70df8_row3_col3" class="data row3 col3" >Flatten</td>
#       <td id="T_70df8_row3_col4" class="data row3 col4" >[None, 6400]</td>
#       <td id="T_70df8_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_70df8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_70df8_row4_col0" class="data row4 col0" >Conv2D</td>
#       <td id="T_70df8_row4_col1" class="data row4 col1" >[None, 5, 5, 16]</td>
#       <td id="T_70df8_row4_col2" class="data row4 col2" >2320</td>
#       <td id="T_70df8_row4_col3" class="data row4 col3" >Dense</td>
#       <td id="T_70df8_row4_col4" class="data row4 col4" >[None, 3]</td>
#       <td id="T_70df8_row4_col5" class="data row4 col5" >19203.000000</td>
#     </tr>
#     <tr>
#       <th id="T_70df8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_70df8_row5_col0" class="data row5 col0" >MaxPooling2D</td>
#       <td id="T_70df8_row5_col1" class="data row5 col1" >[None, 2, 2, 16]</td>
#       <td id="T_70df8_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_70df8_row5_col3" class="data row5 col3" >None</td>
#       <td id="T_70df8_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_70df8_row5_col5" class="data row5 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70df8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_70df8_row6_col0" class="data row6 col0" >Dropout</td>
#       <td id="T_70df8_row6_col1" class="data row6 col1" >[None, 2, 2, 16]</td>
#       <td id="T_70df8_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_70df8_row6_col3" class="data row6 col3" >None</td>
#       <td id="T_70df8_row6_col4" class="data row6 col4" >None</td>
#       <td id="T_70df8_row6_col5" class="data row6 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70df8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_70df8_row7_col0" class="data row7 col0" >Flatten</td>
#       <td id="T_70df8_row7_col1" class="data row7 col1" >[None, 64]</td>
#       <td id="T_70df8_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_70df8_row7_col3" class="data row7 col3" >None</td>
#       <td id="T_70df8_row7_col4" class="data row7 col4" >None</td>
#       <td id="T_70df8_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70df8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_70df8_row8_col0" class="data row8 col0" >Dense</td>
#       <td id="T_70df8_row8_col1" class="data row8 col1" >[None, 50]</td>
#       <td id="T_70df8_row8_col2" class="data row8 col2" >3250</td>
#       <td id="T_70df8_row8_col3" class="data row8 col3" >None</td>
#       <td id="T_70df8_row8_col4" class="data row8 col4" >None</td>
#       <td id="T_70df8_row8_col5" class="data row8 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70df8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_70df8_row9_col0" class="data row9 col0" >Dropout</td>
#       <td id="T_70df8_row9_col1" class="data row9 col1" >[None, 50]</td>
#       <td id="T_70df8_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_70df8_row9_col3" class="data row9 col3" >None</td>
#       <td id="T_70df8_row9_col4" class="data row9 col4" >None</td>
#       <td id="T_70df8_row9_col5" class="data row9 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70df8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_70df8_row10_col0" class="data row10 col0" >Dense</td>
#       <td id="T_70df8_row10_col1" class="data row10 col1" >[None, 3]</td>
#       <td id="T_70df8_row10_col2" class="data row10 col2" >153</td>
#       <td id="T_70df8_row10_col3" class="data row10 col3" >None</td>
#       <td id="T_70df8_row10_col4" class="data row10 col4" >None</td>
#       <td id="T_70df8_row10_col5" class="data row10 col5" >nan</td>
#     </tr>
#   </tbody>
# </tab

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
import keras_tuner as kt
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers

#Define model structure & parameter search space with function
def build_model(hp):
    with tf.device('/device:GPU:0'): # "/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.
                                 
        model = Sequential()
        model.add(Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', input_shape=[10, 10, 3]))
        model.add(Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
        model.add(MaxPooling2D(pool_size=2)) 
        model.add(Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
        model.add(Conv2D(filters=hp.Int("filters", min_value=8, max_value=32, step=8), #range 8-32 inclusive, minimum step between tested values is 8
                         kernel_size=3, padding='same', activation='relu'))
        model.add(MaxPooling2D(pool_size=2))
        model.add(Dropout(0.3))
        model.add(Flatten())
        model.add(Dense(50, activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(3, activation='softmax'))

        # Compile model...
        model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

        return model 

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="val_accuracy", # objective to optimize
    max_trials=2, #max number of trials to run during search
    executions_per_trial=1, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(x_train_split, y_train_split, epochs=1, validation_data=(x_val, y_val))
# Out:
# Trial 2 Complete [00h 00m 04s]
# val_accuracy: 0.6046332120895386
#
# Best val_accuracy So Far: 0.6046332120895386
# Total elapsed time: 00h 00m 11s

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=X_train, y=y_train, epochs=1)
# Out:
# 203/203 [==============================] - 4s 14ms/step - loss: 1.1241 - accuracy: 0.4564

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted y values (Model 3)
prediction_column_index=tuned_model.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 3 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 286/286 [==============================] - 3s 9ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 3
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2651

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_22367_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 53.9%, transparent 53.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 54.0%, transparent 54.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 55.5%, transparent 55.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 59.2%, transparent 59.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row0_col4, #T_22367_row0_col5, #T_22367_row0_col6, #T_22367_row0_col7, #T_22367_row0_col8, #T_22367_row0_col9, #T_22367_row0_col10, #T_22367_row0_col11, #T_22367_row0_col12, #T_22367_row0_col13, #T_22367_row0_col14, #T_22367_row0_col15, #T_22367_row0_col16, #T_22367_row0_col17, #T_22367_row0_col18, #T_22367_row0_col19, #T_22367_row0_col20, #T_22367_row0_col21, #T_22367_row1_col4, #T_22367_row1_col5, #T_22367_row1_col6, #T_22367_row1_col7, #T_22367_row1_col8, #T_22367_row1_col9, #T_22367_row1_col10, #T_22367_row1_col11, #T_22367_row1_col12, #T_22367_row1_col13, #T_22367_row1_col14, #T_22367_row1_col15, #T_22367_row1_col16, #T_22367_row1_col17, #T_22367_row1_col18, #T_22367_row1_col19, #T_22367_row1_col20, #T_22367_row1_col21, #T_22367_row2_col4, #T_22367_row2_col5, #T_22367_row2_col6, #T_22367_row2_col7, #T_22367_row2_col8, #T_22367_row2_col9, #T_22367_row2_col10, #T_22367_row2_col11, #T_22367_row2_col12, #T_22367_row2_col13, #T_22367_row2_col14, #T_22367_row2_col15, #T_22367_row2_col16, #T_22367_row2_col17, #T_22367_row2_col18, #T_22367_row2_col19, #T_22367_row2_col20, #T_22367_row2_col21 {
#   text-align: center;
# }
# #T_22367_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 51.2%, transparent 51.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 50.7%, transparent 50.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 52.7%, transparent 52.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 54.4%, transparent 54.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 45.2%, transparent 45.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 44.6%, transparent 44.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 56.9%, transparent 56.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22367_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_22367_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >dense_layers</th>
#       <th class="col_heading level0 col11" >dropout_layers</th>
#       <th class="col_heading level0 col12" >conv2d_layers</th>
#       <th class="col_heading level0 col13" >flatten_layers</th>
#       <th class="col_heading level0 col14" >maxpooling2d_layers</th>
#       <th class="col_heading level0 col15" >relu_act</th>
#       <th class="col_heading level0 col16" >softmax_act</th>
#       <th class="col_heading level0 col17" >loss</th>
#       <th class="col_heading level0 col18" >optimizer</th>
#       <th class="col_heading level0 col19" >memory_size</th>
#       <th class="col_heading level0 col20" >username</th>
#       <th class="col_heading level0 col21" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22367_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22367_row0_col0" class="data row0 col0" >53.86%</td>
#       <td id="T_22367_row0_col1" class="data row0 col1" >54.04%</td>
#       <td id="T_22367_row0_col2" class="data row0 col2" >55.52%</td>
#       <td id="T_22367_row0_col3" class="data row0 col3" >59.17%</td>
#       <td id="T_22367_row0_col4" class="data row0 col4" >keras</td>
#       <td id="T_22367_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_22367_row0_col6" class="data row0 col6" >True</td>
#       <td id="T_22367_row0_col7" class="data row0 col7" >Sequential</td>
#       <td id="T_22367_row0_col8" class="data row0 col8" >11</td>
#       <td id="T_22367_row0_col9" class="data row0 col9" >10811</td>
#       <td id="T_22367_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_22367_row0_col11" class="data row0 col11" >2.000000</td>
#       <td id="T_22367_row0_col12" class="data row0 col12" >4.000000</td>
#       <td id="T_22367_row0_col13" class="data row0 col13" >1</td>
#       <td id="T_22367_row0_col14" class="data row0 col14" >2.000000</td>
#       <td id="T_22367_row0_col15" class="data row0 col15" >5</td>
#       <td id="T_22367_row0_col16" class="data row0 col16" >1</td>
#       <td id="T_22367_row0_col17" class="data row0 col17" >str</td>
#       <td id="T_22367_row0_col18" class="data row0 col18" >RMSprop</td>
#       <td id="T_22367_row0_col19" class="data row0 col19" >44936</td>
#       <td id="T_22367_row0_col20" class="data row0 col20" >COMS_NNDL</td>
#       <td id="T_22367_row0_col21" class="data row0 col21" >1</td>
#     </tr>
#     <tr>
#       <th id="T_22367_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22367_row1_col0" class="data row1 col0" >51.16%</td>
#       <td id="T_22367_row1_col1" class="data row1 col1" >50.74%</td>
#       <td id="T_22367_row1_col2" class="data row1 col2" >52.75%</td>
#       <td id="T_22367_row1_col3" class="data row1 col3" >54.38%</td>
#       <td id="T_22367_row1_col4" class="data row1 col4" >keras</td>
#       <td id="T_22367_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_22367_row1_col6" class="data row1 col6" >True</td>
#       <td id="T_22367_row1_col7" class="data row1 col7" >Sequential</td>
#       <td id="T_22367_row1_col8" class="data row1 col8" >5</td>
#       <td id="T_22367_row1_col9" class="data row1 col9" >27779</td>
#       <td id="T_22367_row1_col10" class="data row1 col10" >4</td>
#       <td id="T_22367_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_22367_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_22367_row1_col13" class="data row1 col13" >1</td>
#       <td id="T_22367_row1_col14" class="data row1 col14" >nan</td>
#       <td id="T_22367_row1_col15" class="data row1 col15" >3</td>
#       <td id="T_22367_row1_col16" class="data row1 col16" >1</td>
#       <td id="T_22367_row1_col17" class="data row1 col17" >str</td>
#       <td id="T_22367_row1_col18" class="data row1 col18" >RMSprop</td>
#       <td id="T_22367_row1_col19" class="data row1 col19" >112168</td>
#       <td id="T_22367_row1_col20" class="data row1 col20" >COMS_NNDL</td>
#       <td id="T_22367_row1_col21" class="data

# %%
# Compare two or more models 
data=mycompetition.compare_models([1, 2, 3], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_7bb95_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_7bb95_row0_col0, #T_7bb95_row0_col6, #T_7bb95_row1_col0, #T_7bb95_row1_col6, #T_7bb95_row3_col0, #T_7bb95_row3_col6, #T_7bb95_row4_col0, #T_7bb95_row4_col6 {
#   background: #fdcdac;
#   color: black;
#   color: black;
# }
# #T_7bb95_row0_col1, #T_7bb95_row0_col2, #T_7bb95_row0_col4, #T_7bb95_row0_col5, #T_7bb95_row0_col7, #T_7bb95_row0_col8, #T_7bb95_row1_col1, #T_7bb95_row1_col2, #T_7bb95_row1_col4, #T_7bb95_row1_col5, #T_7bb95_row1_col7, #T_7bb95_row1_col8, #T_7bb95_row2_col1, #T_7bb95_row2_col2, #T_7bb95_row2_col4, #T_7bb95_row2_col5, #T_7bb95_row2_col7, #T_7bb95_row2_col8, #T_7bb95_row3_col1, #T_7bb95_row3_col2, #T_7bb95_row3_col4, #T_7bb95_row3_col5, #T_7bb95_row3_col7, #T_7bb95_row3_col8, #T_7bb95_row4_col1, #T_7bb95_row4_col2, #T_7bb95_row4_col4, #T_7bb95_row4_col5, #T_7bb95_row4_col7, #T_7bb95_row4_col8, #T_7bb95_row5_col1, #T_7bb95_row5_col2, #T_7bb95_row5_col3, #T_7bb95_row5_col4, #T_7bb95_row5_col5, #T_7bb95_row5_col7, #T_7bb95_row5_col8, #T_7bb95_row6_col1, #T_7bb95_row6_col2, #T_7bb95_row6_col3, #T_7bb95_row6_col4, #T_7bb95_row6_col5, #T_7bb95_row6_col7, #T_7bb95_row6_col8, #T_7bb95_row7_col1, #T_7bb95_row7_col2, #T_7bb95_row7_col3, #T_7bb95_row7_col4, #T_7bb95_row7_col5, #T_7bb95_row7_col7, #T_7bb95_row7_col8, #T_7bb95_row8_col1, #T_7bb95_row8_col2, #T_7bb95_row8_col3, #T_7bb95_row8_col4, #T_7bb95_row8_col5, #T_7bb95_row8_col7, #T_7bb95_row8_col8, #T_7bb95_row9_col1, #T_7bb95_row9_col2, #T_7bb95_row9_col3, #T_7bb95_row9_col4, #T_7bb95_row9_col5, #T_7bb95_row9_col7, #T_7bb95_row9_col8, #T_7bb95_row10_col1, #T_7bb95_row10_col2, #T_7bb95_row10_col3, #T_7bb95_row10_col4, #T_7bb95_row10_col5, #T_7bb95_row10_col7, #T_7bb95_row10_col8 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_7bb95_row0_col3, #T_7bb95_row1_col3, #T_7bb95_row2_col3, #T_7bb95_row4_col3, #T_7bb95_row8_col0, #T_7bb95_row8_col6, #T_7bb95_row10_col0, #T_7bb95_row10_col6 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_7bb95_row2_col0, #T_7bb95_row2_col6, #T_7bb95_row5_col0, #T_7bb95_row5_col6 {
#   background: #e6f5c9;
#   color: black;
#   color: black;
# }
# #T_7bb95_row3_col3, #T_7bb95_row7_col0, #T_7bb95_row7_col6 {
#   background: nan;
#   color: black;
#   color: black;
# }
# #T_7bb95_row6_col0, #T_7bb95_row6_col6, #T_7bb95_row9_col0, #T_7bb95_row9_col6 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_7bb95_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_1_Layer</th>
#       <th class="col_heading level0 col1" >Model_1_Shape</th>
#       <th class="col_heading level0 col2" >Model_1_Params</th>
#       <th class="col_heading level0 col3" >Model_2_Layer</th>
#       <th class="col_heading level0 col4" >Model_2_Shape</th>
#       <th class="col_heading level0 col5" >Model_2_Params</th>
#       <th class="col_heading level0 col6" >Model_3_Layer</th>
#       <th class="col_heading level0 col7" >Model_3_Shape</th>
#       <th class="col_heading level0 col8" >Model_3_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bb95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7bb95_row0_col0" class="data row0 col0" >Conv2D</td>
#       <td id="T_7bb95_row0_col1" class="data row0 col1" >[None, 10, 10, 16]</td>
#       <td id="T_7bb95_row0_col2" class="data row0 col2" >448</td>
#       <td id="T_7bb95_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_7bb95_row0_col4" class="data row0 col4" >[None, 10, 10, 64]</td>
#       <td id="T_7bb95_row0_col5" class="data row0 col5" >256.000000</td>
#       <td id="T_7bb95_row0_col6" class="data row0 col6" >Conv2D</td>
#       <td id="T_7bb95_row0_col7" class="data row0 col7" >[None, 10, 10, 16]</td>
#       <td id="T_7bb95_row0_col8" class="data row0 col8" >448</td>
#     </tr>
#     <tr>
#       <th id="T_7bb95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7bb95_row1_col0" class="data row1 col0" >Conv2D</td>
#       <td id="T_7bb95_row1_col1" class="data row1 col1" >[None, 10, 10, 16]</td>
#       <td id="T_7bb95_row1_col2" class="data row1 col2" >2320</td>
#       <td id="T_7bb95_row1_col3" class="data row1 col3" >Dense</td>
#       <td id="T_7bb95_row1_col4" class="data row1 col4" >[None, 10, 10, 64]</td>
#       <td id="T_7bb95_row1_col5" class="data row1 col5" >4160.000000</td>
#       <td id="T_7bb95_row1_col6" class="data row1 col6" >Conv2D</td>
#       <td id="T_7bb95_row1_col7" class="data row1 col7" >[None, 10, 10, 16]</td>
#       <td id="T_7bb95_row1_col8" class="data row1 col8" >2320</td>
#     </tr>
#     <tr>
#       <th id="T_7bb95_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_